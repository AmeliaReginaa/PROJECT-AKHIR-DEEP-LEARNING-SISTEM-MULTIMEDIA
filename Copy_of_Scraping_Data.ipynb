# %% [markdown]
# <a href="https://colab.research.google.com/github/AmeliaReginaa/PROJECT-AKHIR-DEEP-LEARNING-SISTEM-MULTIMEDIA/blob/main/Copy_of_Scraping_Data.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install google-play-scraper pandas
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.2/50.2 kB 1.7 MB/s eta 0:00:00
# ...

# %%
from google_play_scraper import reviews, Sort
import pandas as pd
import os

def scrape_app(app_id, filename):
    result, _ = reviews(
        app_id,
        lang='id',
        country='id',
        sort=Sort.NEWEST,
        count=5000
    )

    df = pd.DataFrame(result)
    df = df[['content', 'score', 'at']]

    # Create the 'data' directory if it doesn't exist
    os.makedirs('data', exist_ok=True)

    df.to_csv(f"data/{filename}", index=False)
    print(f"{filename} saved!")

if __name__ == "__main__":
    scrape_app('com.gojek.app', 'gojek_reviews.csv')
    scrape_app('com.grabtaxi.passenger', 'grab_reviews.csv')
# Out:
# gojek_reviews.csv saved!
# grab_reviews.csv saved!

# %%
from google.colab import files

files.download('/content/data/gojek_reviews.csv')
files.download('/content/data/grab_reviews.csv')
